# %%
import numpy as np
import pandas as pd
import os

# %%
def loadCSV(filename):
    file = filename
    if '.csv' not in filename:
        file += '.csv'
    data = pd.read_csv(file, encoding = 'ISO-8859-1')
    return data

# %%
csvFile = "altered_hate_speech"
data = loadCSV(csvFile)

# %%
data.head(20)
# Out:
#                                            tweet_text  confidence  tweet_class
# 0        Warning: penny boards will make you a faggot      0.6013            1
# 1                                          Fuck dykes      0.7227            2
# 2   @sizzurp__ @ILIKECATS74 @yoPapi_chulo @brandon...      0.5229            2
# 3   "@jayswaggkillah: "@JacklynAnnn: @jayswaggkill...      0.5184            2
# 4   @Zhugstubble You heard me bitch but any way I'...      0.5185            1
# 5   @elaynay your a dirty terrorist and your relig...      0.8816            2
# 6   RT @ivanrabago_: @_WhitePonyJr_ looking like f...      0.5207            2
# 7   Well I thought you knew actually RT @KingHorse...      0.5619            2
# 8        @Stonisnipezz I know. It was a joke, faggot.      0.6419            1
# 9   I'm tired of people saying I look like my brot...      0.6407            1
# 10  #VoteBlue2014 Yeah. CUZ 8 million people in fa...      0.7619            2
# 11  @AndreBerto word is you use roids, stupid hypo...      0.5606            2
# 12                            I hate faggots like you      0.8435            2
# 13  @MoriTaheripour shut up nigger whore! Hope u g...      0.8414            2
# 14  @Oprah @3LWTV Fuck you nigger sheboon. Hope yo...      0.8826            2
# 15  They used to tie both ends of a niggers legs t...      0.7620            2
# 16  Good night fags and fagettes (that's the femal...      0.6833            2
# 17  I cant stand no crybaby ass nigga. If you gonn...      0.5204            1
# 18  RT @nerdkiller669: @ShinSnipes no you're a nigger      0.6410            2
# 19  "I'll fuck you til you love me faggot" - Mike ...      0.6419            1

# %%
data.tail(20)
# Out:
#                                               tweet_text  confidence  \
# 14489          @LenaOverFlowers I'm not even a coon girl      1.0000
# 14490  From what I've seen men and women coon at the ...      0.6633
# 14491  "BW,take care of me! pls buy my coon ass somet...      0.6616
# 14492  Interesting data on quantifying value of the I...      1.0000
# 14493                   @aryan_twr60 thank you_ÃÂ«ÃÃ_      1.0000
# 14494  @sardesairajdeep @DwaipayanM if he is Aryan th...      0.6579
# 14495  @sardesairajdeep sir if he is Aryan then #mall...      1.0000
# 14496  Radio Nordfront interview a Russian patriot an...      1.0000
# 14497  @nupursanon hope u check ur fb messages, all m...      1.0000
# 14498  WowÃ_Ã__A Jewish man having his nose measure...      1.0000
# 14499  oldpicsarchive: A Jewish man having his nose m...      1.0000
# 14500  A Jewish man having his nose measured during A...      0.6684
# 14501  AO - aryan huy miss you na!! Happy that i'll b...      1.0000
# 14502  @AryanTimsina Aryan, what is the version of Fifa?      1.0000
# 14503  measured during Aryan race determination tests...      1.0000
# 14504  I'm sorry. Did I offend your white supremacist...      0.3418
# 14505  @tradethecycles Caucasian euro aryan whatever....      0.6804
# 14506  @yadavakhilesh sir a patient named aryan khan ...      1.0000
# 14507  @Iamshivachari  Happy birthday bro _ÃÂ«ÃÃ_ ...      1.0000
# 14508  @Hajrahkiayni Aryan Kapoor is such a cute name...      1.0000
#
#        tweet_class
# 14489            1
# 14490            2
# 14491            1
# 14492            0
# 14493            0
# 14494            0
# 14495            0
# 14496            0
# 14497            0
# 14498            0
# 14499            0
# 14500            0
# 14501            0
# 14502            0
# 14503            0
# 14504            0
# 14505            0
# 14506            0
# 14507            0
# 14508            0

# %% [markdown]
# # Making all tweet_text Lowercase

# %%
data["tweet_text"] = data["tweet_text"].apply(lambda x: x.lower())

# %%
data.head(20)
# Out:
#                                            tweet_text  confidence  tweet_class
# 0        warning: penny boards will make you a faggot      0.6013            1
# 1                                          fuck dykes      0.7227            2
# 2   @sizzurp__ @ilikecats74 @yopapi_chulo @brandon...      0.5229            2
# 3   "@jayswaggkillah: "@jacklynannn: @jayswaggkill...      0.5184            2
# 4   @zhugstubble you heard me bitch but any way i'...      0.5185            1
# 5   @elaynay your a dirty terrorist and your relig...      0.8816            2
# 6   rt @ivanrabago_: @_whiteponyjr_ looking like f...      0.5207            2
# 7   well i thought you knew actually rt @kinghorse...      0.5619            2
# 8        @stonisnipezz i know. it was a joke, faggot.      0.6419            1
# 9   i'm tired of people saying i look like my brot...      0.6407            1
# 10  #voteblue2014 yeah. cuz 8 million people in fa...      0.7619            2
# 11  @andreberto word is you use roids, stupid hypo...      0.5606            2
# 12                            i hate faggots like you      0.8435            2
# 13  @moritaheripour shut up nigger whore! hope u g...      0.8414            2
# 14  @oprah @3lwtv fuck you nigger sheboon. hope yo...      0.8826            2
# 15  they used to tie both ends of a niggers legs t...      0.7620            2
# 16  good night fags and fagettes (that's the femal...      0.6833            2
# 17  i cant stand no crybaby ass nigga. if you gonn...      0.5204            1
# 18  rt @nerdkiller669: @shinsnipes no you're a nigger      0.6410            2
# 19  "i'll fuck you til you love me faggot" - mike ...      0.6419            1

# %%
data.tail(20)
# Out:
#                                               tweet_text  confidence  \
# 14489          @lenaoverflowers i'm not even a coon girl      1.0000
# 14490  from what i've seen men and women coon at the ...      0.6633
# 14491  "bw,take care of me! pls buy my coon ass somet...      0.6616
# 14492  interesting data on quantifying value of the i...      1.0000
# 14493                   @aryan_twr60 thank you_ãâ«ãã_      1.0000
# 14494  @sardesairajdeep @dwaipayanm if he is aryan th...      0.6579
# 14495  @sardesairajdeep sir if he is aryan then #mall...      1.0000
# 14496  radio nordfront interview a russian patriot an...      1.0000
# 14497  @nupursanon hope u check ur fb messages, all m...      1.0000
# 14498  wowã_ã__a jewish man having his nose measure...      1.0000
# 14499  oldpicsarchive: a jewish man having his nose m...      1.0000
# 14500  a jewish man having his nose measured during a...      0.6684
# 14501  ao - aryan huy miss you na!! happy that i'll b...      1.0000
# 14502  @aryantimsina aryan, what is the version of fifa?      1.0000
# 14503  measured during aryan race determination tests...      1.0000
# 14504  i'm sorry. did i offend your white supremacist...      0.3418
# 14505  @tradethecycles caucasian euro aryan whatever....      0.6804
# 14506  @yadavakhilesh sir a patient named aryan khan ...      1.0000
# 14507  @iamshivachari  happy birthday bro _ãâ«ãã_ ...      1.0000
# 14508  @hajrahkiayni aryan kapoor is such a cute name...      1.0000
#
#        tweet_class
# 14489            1
# 14490            2
# 14491            1
# 14492            0
# 14493            0
# 14494            0
# 14495            0
# 14496            0
# 14497            0
# 14498            0
# 14499            0
# 14500            0
# 14501            0
# 14502            0
# 14503            0
# 14504            0
# 14505            0
# 14506            0
# 14507            0
# 14508            0

# %% [markdown]
# # Filter, Distill, and Standardize Tweets

# %% [markdown]
# 1) Extra whitespace removed
#
# 2) Punctuation removed
#
# 3) Hashtag character removed
#
# 3) Garbage Characters removed
#
# 4) @[twitter_handle] replaced with [@]
#
# 5) https:// links replaced with [LINK]

# %%
validCharacters = 'abcdefghijklmnopqrstuvwxyz1234567890@'

# %%
for row in range(0, len(data["tweet_text"])):
    original_tweet = data["tweet_text"][row]
    words = original_tweet.split()
    
    for i in range(0, len(words)):
        if words[i][0] == '@':
            words[i] = "[@]"
        elif "http" in words[i]:
            words[i] = "[LINK]"
        else:
            filtered_word = ''.join(filter(lambda x: x in validCharacters, words[i]))
            words[i] = filtered_word
    
    filtered_tweet = " ".join(words)
    
    data["tweet_text"] = data["tweet_text"].replace(original_tweet, filtered_tweet)

# %%
data.head(20)
# Out:
#                                            tweet_text  confidence  tweet_class
# 0         warning penny boards will make you a faggot      0.6013            1
# 1                                          fuck dykes      0.7227            2
# 2   [@] [@] [@] [@] [@] at least i dont look like ...      0.5229            2
# 3   @jayswaggkillah @jacklynannn [@] is a fag jack...      0.5184            2
# 4   [@] you heard me bitch but any way im back th ...      0.5185            1
# 5   [@] your a dirty terrorist and your religion i...      0.8816            2
# 6                     rt [@] [@] looking like faggots      0.5207            2
# 7   well i thought you knew actually rt [@] man wh...      0.5619            2
# 8                     [@] i know it was a joke faggot      0.6419            1
# 9   im tired of people saying i look like my broth...      0.6407            1
# 10  voteblue2014 yeah cuz 8 million people in fagg...      0.7619            2
# 11  [@] word is you use roids stupid hypocrite lyi...      0.5606            2
# 12                            i hate faggots like you      0.8435            2
# 13  [@] shut up nigger whore hope u get raped by o...      0.8414            2
# 14  [@] [@] fuck you nigger sheboon hope you r str...      0.8826            2
# 15  they used to tie both ends of a niggers legs t...      0.7620            2
# 16  good night fags and fagettes thats the female ...      0.6833            2
# 17  i cant stand no crybaby ass nigga if you gonna...      0.5204            1
# 18                       rt [@] [@] no youre a nigger      0.6410            2
# 19    ill fuck you til you love me faggot  mike tyson      0.6419            1

# %%
data.tail(20)
# Out:
#                                               tweet_text  confidence  \
# 14489                        [@] im not even a coon girl      1.0000
# 14490  from what ive seen men and women coon at the s...      0.6633
# 14491  bwtake care of me pls buy my coon ass somethin...      0.6616
# 14492  interesting data on quantifying value of the i...      1.0000
# 14493                                      [@] thank you      1.0000
# 14494  [@] [@] if he is aryan then mallikarjun will s...      0.6579
# 14495  [@] sir if he is aryan then mallikarjun will a...      1.0000
# 14496  radio nordfront interview a russian patriot an...      1.0000
# 14497  [@] hope u check ur fb messages all message re...      1.0000
# 14498  wowa jewish man having his nose measured durin...      1.0000
# 14499  oldpicsarchive a jewish man having his nose me...      1.0000
# 14500  a jewish man having his nose measured during a...      0.6684
# 14501  ao  aryan huy miss you na happy that ill be ab...      1.0000
# 14502              [@] aryan what is the version of fifa      1.0000
# 14503  measured during aryan race determination tests...      1.0000
# 14504  im sorry did i offend your white supremacist a...      0.3418
# 14505  [@] caucasian euro aryan whatever really doesn...      0.6804
# 14506  [@] sir a patient named aryan khan village mee...      1.0000
# 14507  [@] happy birthday bro  have an happy year ahead       1.0000
# 14508  [@] aryan kapoor is such a cute name tho  d we...      1.0000
#
#        tweet_class
# 14489            1
# 14490            2
# 14491            1
# 14492            0
# 14493            0
# 14494            0
# 14495            0
# 14496            0
# 14497            0
# 14498            0
# 14499            0
# 14500            0
# 14501            0
# 14502            0
# 14503            0
# 14504            0
# 14505            0
# 14506            0
# 14507            0
# 14508            0

# %% [markdown]
# # Calculate Frequency of Unique Words By Class

# %%
def iterateFreq(dictionary, word):
    if dictionary.get(word, False):
        dictionary[word] += 1
    else:
        dictionary[word] = 1

# %%
def wordFrequencies(dataframe):
    all_tweets = {}
    neutral = {}
    offensive = {}
    hate = {}
    
    for index, row in dataframe.iterrows():
        tweet = row[0]
        tweet_class = row[2]
        
        tweet_words = tweet.split()
        
        for word in tweet_words:
            if tweet_class == 0:
                iterateFreq(neutral, word)
            elif tweet_class == 1:
                iterateFreq(offensive, word)
            elif tweet_class == 2:
                iterateFreq(hate, word)
                
            iterateFreq(all_tweets, word)
    
    return all_tweets, neutral, offensive, hate

# %%
def dispWordFreq(dictionary):
    unique_words = sorted( ((v,k) for k, v in dictionary.items()), reverse = True)
    for v, k in unique_words:
        word_val = "%s: %d" % (k, v)
        print(word_val)

# %%
all_wf, neutral_wf, offensive_wf, hate_wf = wordFrequencies(data)

# %%
len(all_wf)
# Out:
# 17933

# %%
len(neutral_wf)
# Out:
# 13471

# %%
len(offensive_wf)
# Out:
# 7330

# %%
len(hate_wf)
# Out:
# 4349

# %% [markdown]
# # Save Altered CSV

# %%
path = os.getcwd()

# %%
new_csv = "/processed_hate_speech.csv"
filepath = path + new_csv

# %%
data.to_csv(filepath, index = None, header = True)
